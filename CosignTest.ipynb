# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from numpy import count_nonzero

# %%
def evaluateSummary(data, aiSummary, handSummary):
  count_vectorizer = CountVectorizer()
  evaluation = count_vectorizer.fit_transform([aiSummary, handSummary])
  return cosine_similarity(evaluation, evaluation)[0][1]

def evaluatePrecision(aiSummary, handSummary):
  count_vectorizer = CountVectorizer()
  evaluation = count_vectorizer.fit_transform([aiSummary, handSummary])
  y_true = evaluation[0].toarray()
  y_pred = evaluation[1].toarray()
  return precision_score(y_true[0], y_pred[0], average='macro')


#def evaluateRecall(aiSummary, handSummary):
#  count_vectorizer = CountVectorizer()
#  evaluation = count_vectorizer.fit_transform([aiSummary, handSummary])
#  y_true = evaluation[0].toarray()
#  y_pred = evaluation[1].toarray()
#  return recall_score(y_true[0], y_pred[0], average='macro')

# %%
randomData = "The man was in pain, for he had no gains and thus profane"
sent1 = "Man is no gain man riperino"
sent2 = "Man is of profane man nani"

print(evaluateSummary(randomData, sent1, sent2))
print(evaluatePrecision(sent1, sent2))
#print(evaluateRecall(sent1, sent2))
# Out:
# 0.6249999999999999
# 0.4166666666666667
