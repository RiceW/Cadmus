# %%
import pandas as pd
import nltk
import json
import os

# %%
test = ["I like cats","Dogs play with balls"]

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir("/content/drive/My Drive/Cadmus/hackathon_dataset/")
os.listdir()
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-9d54df421eda> in <module>()
#       1 from google.colab import drive
#       2 drive.mount('/content/drive')
# ----> 3 os.chdir("/content/drive/My Drive/Cadmus/hackathon_dataset/")
#       4 os.listdir()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Cadmus/hackathon_dataset/'

# %%
dataframeTest = pd.read_json('test.json')
#print (dataframeTest.to_string())

dataframeTrain = pd.read_json('train.json')
#print (dataframeTrain.to_string())

dataframeVal = pd.read_json('val.json')
#print (dataframeVal.to_string())

# %%
dataframeTrain.columns
# Out:
# Index(['id', 'summary', 'dialogue'], dtype='object')

# %%
dataframeTrain.shape
# Out:
# (14732, 3)

# %%
testDict = dataframeTest['summary'].to_dict()
#print(testDict)
trainDict = dataframeTrain['summary'].to_dict()
#print(trainDict)
valDict = dataframeVal['summary'].to_dict()
#print(valDict)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
#Warren's wonderful code 

import pandas as pd
import nltk
import json
import os
nltk.download('punkt') #Not sure what this is but the error code recommended 'punkt' to be downloaded 
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer


nltk.download('stopwords')
from nltk.corpus import stopwords
stopwords = stopwords.words('english') #making sure were in the english language here 

from string import punctuation 
punctuation = list(punctuation)

print("Willy Wonka walked to the store, there he found beautiful pieces of bubblegum and ate it.")
tokens = word_tokenize("Willy Wonka walked to the store, there he found beautiful pieces of bubblegum and ate it.")
print(len(tokens)) #printing number of items in pre cleaned token 

cleaned_tokens = [token for token in tokens if token not in stopwords 

                  and token not in punctuation] #filtering out stopwords and punctuation 
print(len(cleaned_tokens))#printing number of items in cleaned_tokens 
print(cleaned_tokens)

lmtzr = WordNetLemmatizer()
lemmatized = [lmtzr.lemmatize(word) for word in cleaned_tokens]
 
print(lemmatized)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Willy Wonka walked to the store, there he found beautiful pieces of bubblegum and ate it.
# 18
# 9
# ['Willy', 'Wonka', 'walked', 'store', 'found', 'beautiful', 'pieces', 'bubblegum', 'ate']
# ['Willy', 'Wonka', 'walked', 'store', 'found', 'beautiful', 'piece', 'bubblegum', 'ate']

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize

nltk.download('punkt')
nltk.download('wordnet')

sentence = {'1': 'i like cars', '2': 'cats are the best'}

lmtzr = WordNetLemmatizer()
lemmatized = [[lmtzr.lemmatize(word) for word in word_tokenize(s)] for s in sentence.values()]
print(lemmatized)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [['i', 'like', 'car'], ['cat', 'are', 'the', 'best']]

# %%
# Vyshnavi's Code

def clean_convo(convos):
  cleaned_tokens=[]
  for convo in convos:
    tokens = word_tokenize(convo) 
    cleaned_tokens.append([token for token in tokens if token not in stopwords and token not in punctuation])
  return cleaned_tokens

tokenized_cleaned_train_dialogue = clean_convo(dataframeTrain['dialogue'])
tokenized_cleaned_test_dialogue = clean_convo(dataframeTest['dialogue'])
tokenized_cleaned_val_dialogue = clean_convo(dataframeVal['dialogue'])

# %%
train_summary = dataframeTrain['summary']
test_summary = dataframeTest['summary']
val_summary = dataframeVal['summary']

# %%
tokenized_cleaned_train_dialogue[1]
# Out:
# ['Olivia',
#  'Who',
#  'voting',
#  'election',
#  'Oliver',
#  'Liberals',
#  'always',
#  'Olivia',
#  'Me',
#  'Oliver',
#  'Great']

# %%
dataframeTrain['dialogue'][1]
# Out:
# 'Olivia: Who are you voting for in this election? \r\nOliver: Liberals as always.\r\nOlivia: Me too!!\r\nOliver: Great'

# %%
def word_frequency_score(dialogue):
  word_frequencies={}
  for word in dialogue:
    if word not in word_frequencies.keys():
      word_frequencies[word] = 1
    else:
      word_frequencies[word] += 1

  maximum_frequency = max(word_frequencies.values())

  for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word]/maximum_frequency)
    
  return word_frequencies

# %%
word_frequencies = word_frequency_score(tokenized_cleaned_train_dialogue[1])

# %%
word_frequencies
# Out:
# {'Great': 0.5,
#  'Liberals': 0.5,
#  'Me': 0.5,
#  'Oliver': 1.0,
#  'Olivia': 1.0,
#  'Who': 0.5,
#  'always': 0.5,
#  'election': 0.5,
#  'voting': 0.5}

# %%
tokenized_cleaned_train_dialogue[1]
# Out:
# ['Olivia',
#  'Who',
#  'voting',
#  'election',
#  'Oliver',
#  'Liberals',
#  'always',
#  'Olivia',
#  'Me',
#  'Oliver',
#  'Great']

# %%
#Ritika's Code
def calculate_sentence_scores(sentence,word_frequencies):
  sentence_scores = {}
#for sent in sentence_list:
  for sent in sentence:
      for word in word_frequencies.keys():
          if sent not in sentence_scores.keys():
              sentence_scores[sent] = word_frequencies[word]
          else:
              sentence_scores[sent] += word_frequencies[word]
  return sentence_scores

# %%
print(tokenized_cleaned_train_dialogue[1])
sentence_scores = calculate_sentence_scores(tokenized_cleaned_train_dialogue[1],word_frequencies)
# Out:
# ['Olivia', 'Who', 'voting', 'election', 'Oliver', 'Liberals', 'always', 'Olivia', 'Me', 'Oliver', 'Great']

# %%
sentence_scores
# Out:
# {'Great': 5.5,
#  'Liberals': 5.5,
#  'Me': 5.5,
#  'Oliver': 11.0,
#  'Olivia': 11.0,
#  'Who': 5.5,
#  'always': 5.5,
#  'election': 5.5,
#  'voting': 5.5}

# %%
import heapq
def find_summary(sentence_scores):
  summary_sentences = heapq.nlargest(7, sentence_scores, key=sentence_scores.get)

  summary = ' '.join(summary_sentences)
  return summary

# %%
summaries = {}
indexes_to_drop = []
count = 0
for sentences in tokenized_cleaned_train_dialogue:
  try:
    word_frequency = word_frequency_score(sentences)
    sentence_scores = calculate_sentence_scores(sentences,word_frequency)
    summary = find_summary(sentence_scores)
    summaries[count] = summary
    count = count+1
  except:
    indexes_to_drop.append(count)
    count = count+1

# %%
#summaries

# %%
summaries[1]
# Out:
# 'Olivia Oliver Who voting election Liberals always'

# %% [markdown]
# <h1> Using Gensim </h1>

# %%
import gensim
from gensim.summarization import summarize

# %%
type(trainDict)
# Out:
# dict

# %%
newtrainDict = str(trainDict[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eed1b94b031b> in <module>()
# ----> 1 newtrainDict = str(trainDict[1])
#
# NameError: name 'trainDict' is not defined

# %%
newtrainDict
# Out:
# '{0: \'Amanda baked cookies and will bring Jerry some tomorrow.\', 1: \'Olivia and Olivier are voting for liberals in this election. \', 2: \'Kim may try the pomodoro technique recommended by Tim to get more stuff done.\', 3: \'Edward thinks he is in love with Bella. Rachel wants Edward to open his door. Rachel is outside. \', 4: \'Sam is confused, because he overheard Rick complaining about him as a roommate. Naomi thinks Sam should talk to Rick. Sam is not sure what to do.\', 5: "Wyatt reminds Neville his wedding anniversary is on the 17th of September. Neville\'s wife is upset and it might be because Neville forgot about their anniversary.", 6: "John didn\'t show up for class due to some work issues with his boss. Cassandra, his teacher told him which exercises to do, and which chapter to study. They are going to meet up for a beer sometime this week after class. ", 7: \'Sarah sends James an instrumental song he might like. James knows the song. The brain connects the songs to the context they were played in and brings to mind the associated memories.\', 8: \'Noah wants to meet, he quit his job, because his boss was a dick.\', 9: "Matt invites Agnes for a date to get to know each other better. They\'ll go to the Georgian restaurant in Kazimierz on Saturday at 6 pm, and he\'ll pick her up on the way to the place.", 10: \'Demi got promoted. She will celebrate that with Lucas at Death & Co at 10 pm.\', 11: \'Mark just shipped the goods and he will send George the tracking number tomorrow.\', 12: \'Anita is at Bologna station.\', 13: \'Arthur is still unemployed. Leon sends him a job offer for junior project manager position. Arthur is interested.\', 14: \'Macca has done ice climbing for the first time today, close to Reykjavik. He enjoyed it very much.\', 15: \'Isabella feels bad after the Christmas party. She got drunk. She is ashamed to go back to work. \', 16: "Lucy owes Tina 50 dollars. She made a transfer but it is Sunday so the payment will be on Tina\'s account on Monday. Tina needs the money because she has been having expanses recently.", 17: \'Betty feels remorse she got drunk last night and went out of control.\', 18: "Mike and Mary are going to visit Mike\'s grandma tonight. Mary will buy her some chocolate.", 19: \'Laura will pick up Kim from work around 7, and they will come back home together.\', 20: "Erin is convinced by Ashley\'s book recommendations, while Seamus and Marcus aren\'t.", 21: "Aria has just run into Charlie Evans. He is now married, with two daughters, and a family business. She has also met Cooper Roy from high school. She used to have a crush on him, now she almost didn\'t recognise him. Maverick and Aria miss the old times and think the world has changed for the worse.", 22: \'Omenah is at home, Anna will be there in a minute.\', 23: "Layla the dog misses Rachel. She is having a knee surgery, because of arthritis. Renee sends a picture of her dog. Rachel getting settled and she\'s looking for a job in teaching. ", 24: \'Jonas will be 10 minutes late. Natalie will let Mary know Jonas will present before she starts.\', 25: "Lawrence doesn\'t like the play of Manchester United. He and Julius complain about the team and Mourinho\'s style.", 26: \'The trip Wayne was going to go on was postponed. Now Jade will be able to go to.\', 27: \'Jason is going to Thailand next week. Natalie will send him pictures of the spices she wants him to buy for her. Then she will remind him about it in two weeks.\', 28: \'Elisa, Sadie, Carol, Liam, Tom and John want to go for drinks tonight at Mombasa. Arthur will come with Alice. Kai will join them around 8. Elisa will book the big corner table for 15 people.\', 29: \'Amy and Hal will have dinner together when he is back home before 7.\', 30: "Ray\'s bike was stolen from the 9th street yesterday even though it was secured. It was a custom bike so now Ray\'s out few grand. Ray wants to post posters in the area so they\'ll get scared and leave it somewhere. Luke had on ...

# %%
short_summary = summarize(newtrainDict[1])
print(short_summary)

# %%
trainDict[1]
# Out:
# 'Olivia and Olivier are voting for liberals in this election. '

# %%
'''
def sentence_frequency_score(sentences): 
  sentenceValue = dict()

  for sentence in sentences:
    word_count_in_sentence = (len(sentence))
    freqTable = word_frequency_score(sentence)
    for wordValue in freqTable:
      if wordValue in sentence.lower():
        if sentence[:] in sentenceValue:
          sentenceValue[sentence[:]] += freqTable[wordValue]
        else:
          sentenceValue[sentence[:]] = freqTable[wordValue]

    sentenceValue[sentence[:]] = sentenceValue[sentence[:]] // word_count_in_sentence

  return sentenceValue
'''
# Out:
# '\ndef sentence_frequency_score(sentences): \n  sentenceValue = dict()\n\n  for sentence in sentences:\n    word_count_in_sentence = (len(sentence))\n    freqTable = word_frequency_score(sentence)\n    for wordValue in freqTable:\n      if wordValue in sentence.lower():\n        if sentence[:] in sentenceValue:\n          sentenceValue[sentence[:]] += freqTable[wordValue]\n        else:\n          sentenceValue[sentence[:]] = freqTable[wordValue]\n\n    sentenceValue[sentence[:]] = sentenceValue[sentence[:]] // word_count_in_sentence\n\n  return sentenceValue\n'

# %%
'''
def find_average_score(sentenceValue) -> int:
    sumValues = 0
    for entry in sentenceValue:
        sumValues += sentenceValue[entry]

    # Average value of a sentence from original text
    average = int(sumValues / len(sentenceValue))

    return average
  '''
# Out:
# '\ndef find_average_score(sentenceValue) -> int:\n    sumValues = 0\n    for entry in sentenceValue:\n        sumValues += sentenceValue[entry]\n\n    # Average value of a sentence from original text\n    average = int(sumValues / len(sentenceValue))\n\n    return average\n  '

# %%
'''
def generate_summary(sentences, sentenceValue, threshold):
    sentence_count = 0
    summary = ''

    for sentence in sentences:
        if sentence[:10] in sentenceValue and sentenceValue[sentence[:10]] > (threshold):
            summary += " " + sentence
            sentence_count += 1

    return summary
'''
# Out:
# '\ndef generate_summary(sentences, sentenceValue, threshold):\n    sentence_count = 0\n    summary = \'\'\n\n    for sentence in sentences:\n        if sentence[:10] in sentenceValue and sentenceValue[sentence[:10]] > (threshold):\n            summary += " " + sentence\n            sentence_count += 1\n\n    return summary\n'
